# %% [markdown]
# ## Importing Libs

# %%
import pandas as pd

# %% [markdown]
# ## Criar DataFrames com base nos Datasets

# %% [markdown]
# ### Customers Dataframe

# %%
# Carregar Dataframe de Clientes (Customers)
df_customers = pd.read_csv('.\datasets\churn_customers.csv')

# %%
# Mostrar as 5 primeiras linhas do DataFrame
df_customers.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %%
# Mostrar os 5 ultimos registros do DataFrame
df_customers.tail(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents
# 7038  6840-RESVB    Male              0     Yes        Yes
# 7039  2234-XADUH  Female              0     Yes        Yes
# 7040  4801-JZAZL  Female              0     Yes        Yes
# 7041  8361-LTMKD    Male              1     Yes         No
# 7042  3186-AJIEK    Male              0      No         No

# %%
# Mostrar estrutura / schema do DataFrame
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %% [markdown]
# ### Services Dataframe

# %%
# Carregar Dataframe de Serviços (Services)
df_services = pd.read_csv('.\datasets\churn_services.csv')

# %%
# Mostrar as 5 primeiras linhas do DataFrame
df_services.head(5)
# Out:
#    customerID PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0  7590-VHVEG           No  No phone service             DSL             No
# 1  5575-GNVDE          Yes                No             DSL            Yes
# 2  3668-QPYBK          Yes                No             DSL            Yes
# 3  7795-CFOCW           No  No phone service             DSL            Yes
# 4  9237-HQITU          Yes                No     Fiber optic             No
#
#   OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies
# 0          Yes               No          No          No              No
# 1           No              Yes          No          No              No
# 2          Yes               No          No          No              No
# 3           No              Yes         Yes          No              No
# 4           No               No          No          No              No

# %%
# Mostrar os 5 ultimos registros do DataFrame
df_services.tail(5)
# Out:
#       customerID PhoneService     MultipleLines InternetService  \
# 7038  6840-RESVB          Yes               Yes             DSL
# 7039  2234-XADUH          Yes               Yes     Fiber optic
# 7040  4801-JZAZL           No  No phone service             DSL
# 7041  8361-LTMKD          Yes               Yes     Fiber optic
# 7042  3186-AJIEK          Yes                No     Fiber optic
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 7038            Yes           No              Yes         Yes         Yes
# 7039             No          Yes              Yes          No         Yes
# 7040            Yes           No               No          No          No
# 7041             No           No               No          No          No
# 7042            Yes           No              Yes         Yes         Yes
#
#      StreamingMovies
# 7038             Yes
# 7039             Yes
# 7040              No
# 7041              No
# 7042             Yes

# %%
# Mostrar estrutura / schema do DataFrame
df_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   PhoneService      7043 non-null   object
#  2   MultipleLines     7043 non-null   object
#  3   InternetService   7043 non-null   object
#  4   OnlineSecurity    7043 non-null   object
#  5   OnlineBackup      7043 non-null   object
#  6   DeviceProtection  7043 non-null   object
#  7   TechSupport       7043 non-null   object
#  8   StreamingTV       7043 non-null   object
#  9   StreamingMovies   7043 non-null   object
# dtypes: object(10)
# memory usage: 550.4+ KB

# %% [markdown]
# ### Contracts Dataframe

# %%
# Carregar Dataframe de Contratos (Contracts)
df_contracts = pd.read_csv('.\datasets\churn_contracts.csv')

# %%
# Mostrar as 5 primeiras linhas do DataFrame
df_contracts.head(5)
# Out:
#    customerID  tenure        Contract PaperlessBilling  \
# 0  7590-VHVEG       1  Month-to-month              Yes
# 1  5575-GNVDE      34        One year               No
# 2  3668-QPYBK       2  Month-to-month              Yes
# 3  7795-CFOCW      45        One year               No
# 4  9237-HQITU       2  Month-to-month              Yes
#
#                PaymentMethod     MonthlyCharges TotalCharges Churn
# 0           Electronic check 29.850000000000001        29.85    No
# 1               Mailed check 56.950000000000003       1889.5    No
# 2               Mailed check 53.850000000000001       108.15   Yes
# 3  Bank transfer (automatic) 42.299999999999997      1840.75    No
# 4           Electronic check 70.700000000000003       151.65   Yes

# %%
# Mostrar os 5 ultimos registros do DataFrame
df_contracts.tail(5)
# Out:
#       customerID  tenure        Contract PaperlessBilling  \
# 7038  6840-RESVB      24        One year              Yes
# 7039  2234-XADUH      72        One year              Yes
# 7040  4801-JZAZL      11  Month-to-month              Yes
# 7041  8361-LTMKD       4  Month-to-month              Yes
# 7042  3186-AJIEK      66        Two year              Yes
#
#                   PaymentMethod      MonthlyCharges TotalCharges Churn
# 7038               Mailed check  84.799999999999997       1990.5    No
# 7039    Credit card (automatic) 103.200000000000003       7362.9    No
# 7040           Electronic check  29.600000000000001       346.45    No
# 7041               Mailed check  74.400000000000006        306.6   Yes
# 7042  Bank transfer (automatic) 105.650000000000006       6844.5    No

# %%
# Mostrar estrutura / schema do DataFrame
df_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   object
#  7   Churn             7043 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 440.3+ KB

# %% [markdown]
# ## Transformacao de Dados

# %%
# Transformar coluna TotalCharges de String para Float
#df_contracts.TotalCharges = pd.to_numeric.astype(float)
#df_contracts.TotalCharges = pd.to_numeric(df_contracts.TotalCharges)
df_contracts.TotalCharges = pd.to_numeric(df_contracts.TotalCharges, errors='coerce')

# %%
# Mostrar estrutura / schema do DataFrame
df_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7032 non-null   float64
#  7   Churn             7043 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 440.3+ KB

# %% [markdown]
# Apos a transformacao da coluna TotalCharges do Dataframe Contracts, a coluna passou a ter 11 valores ausentes (missing values)

# %% [markdown]
# ## Renomear Colunas

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Renomear Coluna no DataFrame, usando rename e dicionario
df_customers.rename(columns={'SeniorCitizen': 'Abobe65Yo'})
# Out:
#       customerID  gender  Abobe65Yo Partner Dependents
# 0     7590-VHVEG  Female          0     Yes         No
# 1     5575-GNVDE    Male          0      No         No
# 2     3668-QPYBK    Male          0      No         No
# 3     7795-CFOCW    Male          0      No         No
# 4     9237-HQITU  Female          0      No         No
# ...          ...     ...        ...     ...        ...
# 7038  6840-RESVB    Male          0     Yes        Yes
# 7039  2234-XADUH  Female          0     Yes        Yes
# 7040  4801-JZAZL  Female          0     Yes        Yes
# 7041  8361-LTMKD    Male          1     Yes         No
# 7042  3186-AJIEK    Male          0      No         No
#
# [7043 rows x 5 columns]

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Criar um Dataframe novo com base nas colunas renomeadas
df_customers_renamed = df_customers.rename(columns={'SeniorCitizen': 'Above65Yo'})

# %%
# Mostrar estrutura do DataFrame novo
df_customers_renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   object
#  1   gender      7043 non-null   object
#  2   Above65Yo   7043 non-null   int64
#  3   Partner     7043 non-null   object
#  4   Dependents  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Aplicar o resultado do rename no proprio DataFrame
df_customers.rename(columns={'SeniorCitizen': 'Above65Yo'}, inplace=True)

# %%
# Mostrar estrutura do DataFrame
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   object
#  1   gender      7043 non-null   object
#  2   Above65Yo   7043 non-null   int64
#  3   Partner     7043 non-null   object
#  4   Dependents  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Rename usando Lista - Modificar todas as colunas
df_customers.columns = [
    'IDCliente', 'Genero', 'Mais65Anos', 'TemParceiro', 'TemDependentes',
]

# %%
# Mostrar estrutura do DataFrame
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   IDCliente       7043 non-null   object
#  1   Genero          7043 non-null   object
#  2   Mais65Anos      7043 non-null   int64
#  3   TemParceiro     7043 non-null   object
#  4   TemDependentes  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %% [markdown]
# ## Unificar Datagrames de Customers, Services e Contracts

# %%
# Contar quantidade de registros por Dataframe
len(df_customers), len(df_services), len(df_contracts)
# Out:
# (7043, 7043, 7043)

# %%
# Renomear colunas
df_services.rename(columns={'customerID': 'IDCliente'}, inplace=True)

# %%
df_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   PhoneService      7043 non-null   object
#  2   MultipleLines     7043 non-null   object
#  3   InternetService   7043 non-null   object
#  4   OnlineSecurity    7043 non-null   object
#  5   OnlineBackup      7043 non-null   object
#  6   DeviceProtection  7043 non-null   object
#  7   TechSupport       7043 non-null   object
#  8   StreamingTV       7043 non-null   object
#  9   StreamingMovies   7043 non-null   object
# dtypes: object(10)
# memory usage: 550.4+ KB

# %%
# Unificar Dataframe de Customers com services, criando um terceiro DataFrame
df_temp = df_customers.merge(df_services, on='IDCliente', how='inner')

# %%
# Mostrar estrutura do DataFrame temp
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65Anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 770.5+ KB

# %%
df_temp.head(5)
# Out:
#     IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0  7590-VHVEG  Female           0         Yes             No           No
# 1  5575-GNVDE    Male           0          No             No          Yes
# 2  3668-QPYBK    Male           0          No             No          Yes
# 3  7795-CFOCW    Male           0          No             No           No
# 4  9237-HQITU  Female           0          No             No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies
# 0               No          No          No              No
# ...

# %%
# Unificar df_temp com Contracts, usando colunas de juncao com nomes distintos
df_churn_temp = df_temp.merge(df_contracts, left_on=['IDCliente'], right_on=['customerID'], how='inner')

# %%
df_churn_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65Anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  customerID        7043 non-null   object
#  15  tenure            7043 non-null   int64
# ...

# %%
# Unificar os 3 DataFrames ao mesmo tempo, com colunas e com nomes diferentes
df_churn = df_customers.merge(df_services, on='IDCliente', how='inner')\
    .merge(df_contracts, left_on=['IDCliente'], right_on=['customerID'])

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65Anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  customerID        7043 non-null   object
#  15  tenure            7043 non-null   int64
# ...

# %%
# Removendo coluna de um DataFrame
df_churn.drop(['customerID'], axis=1, inplace=True)

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65Anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  tenure            7043 non-null   int64
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ## Deteccao de Valores Ausentes

# %%
# Detectar valores ausentes em todas as colunas de um DataFrame
df_churn.isna().sum()
# Out:
# IDCliente            0
# Genero               0
# Mais65Anos           0
# TemParceiro          0
# TemDependentes       0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# Detectar valores ausentes em uma coluna específica
df_churn.TotalCharges.isna().sum()
# Out:
# np.int64(11)

# %%
# Quantas linhas tem pelo menos 1 coluna com valor ausente
df_churn[df_churn.isna().any(axis=1)]
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 488   4472-LVYGI  Female           0         Yes            Yes           No
# 753   3115-CZMZD    Male           0          No            Yes          Yes
# 936   5709-LVOEQ  Female           0         Yes            Yes          Yes
# 1082  4367-NUYAO    Male           0         Yes            Yes          Yes
# 1340  1371-DWPAZ  Female           0         Yes            Yes           No
# 3331  7644-OMVMY    Male           0         Yes            Yes          Yes
# 3826  3213-VVOLG    Male           0         Yes            Yes          Yes
# 4380  2520-SGTTA  Female           0         Yes            Yes          Yes
# 5218  2923-ARZLG    Male           0         Yes            Yes          Yes
# 6670  4075-WKNIU  Female           0         Yes            Yes          Yes
# 6754  2775-SEFEE    Male           0          No            Yes          Yes
#
# ...

# %%
# Quantas colunas tem pelo menos 1 valor ausente
df_churn.isna().any(axis=0).sum()
# Out:
# np.int64(1)

# %% [markdown]
# ## Remover valores ausentes

# %%
# Remover de forma direta e espeficica as colunas que possuem valores ausentes
df_churn.drop(columns=['TotalCharges'], axis=1)
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover colunas com valores ausentes
df_churn.dropna(axis=1)
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover colunas onde todos os valores sao ausentes
df_churn.dropna(how='all', axis=1)
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover linhas com valores ausentes
df_churn.dropna(axis=0)
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover linhas com todos os valores ausentes
df_churn.dropna(how='all', axis=0)
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %% [markdown]
# ## Inputacao de Valores Ausentes

# %%
# Preencher todos os valores ausentes com 0
df_churn.fillna(0)
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Preencher valores padrao conforme o tipo da coluna
df_churn.fillna(value={
    'TotalCharges': 0                     
})
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Preencher todos os valores ausentes de uma coluna com a media
media_TotalCharges = df_churn.TotalCharges.mean()

# %%
media_TotalCharges
# Out:
# np.float64(2283.3004408418656)

# %%
df_churn.fillna(value={'TotalCharges': media_TotalCharges})
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %% [markdown]
# ## Analise Univariada

# %% [markdown]
# - A faixa etaria do cliente tem uma forte associacao com o Churn
# - Um cliente com menos de 6 meses de contrato e mais propenso ao Churn
# - Cliente com contrato mensal e mais propenso ao Churn

# %%
# Contar clients usando a variavel Churn como referencia
df_churn.Churn.value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# Como identificar valores possivels (unicos) numa variavel do DataFrame
df_churn.Churn.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Como e a distribuicao de Clientes (percentual) que abandonaram ou continuam ativos
df_churn.Churn.value_counts(normalize=True)
# Out:
# Churn
# No    0.734630129206304
# Yes   0.265369870793696
# Name: proportion, dtype: float64

# %%
# Plot distribuicao do Churn (Quantidade)
ax = df_churn.Churn.value_counts().plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '5174'), Text(0, 0, '1869')]

# %%
# Plot distribuicao do Churn (Percentual)
ax = df_churn.Churn.value_counts(normalize=True).plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '0.73463'), Text(0, 0, '0.26537')]

# %%
# Quais sao os tipos de contrato
df_churn.Contract.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
# Plot distribuicao do Contract (Quantidade)
ax = df_churn.Contract.value_counts().plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '3875'), Text(0, 0, '1695'), Text(0, 0, '1473')]

# %%
# Plot distribuicao do Contract (Percentual)
ax = df_churn.Contract.value_counts(normalize=True).plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '0.550192'), Text(0, 0, '0.240664'), Text(0, 0, '0.209144')]

# %%
# Histograma do Tempo de Contrato (tenure)
df_churn.tenure.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# - A variavel tempo de contrato (tenure) nao apresenta visualmente uma distribuicao normal.
# - A grande parte dos valores se concentram nos extremos, ou seja, contratos com poucos meses de ativacao e contratos longos, acima aproximadamente dos 65 meses.

# %%
# Histograma do Montlhy Charges
df_churn.MonthlyCharges.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Medidas de Pocicao - Media Tempo de Contrato
df_churn.tenure.mean()
# Out:
# np.float64(32.37114865824223)

# %%
# Medidas de Posicao - Mediana Tempo de Contrato
df_churn.tenure.median()
# Out:
# np.float64(29.0)

# %%
# Medidas de Pocicao - Moda Tempo de Contrato
df_churn.tenure.mode()
# Out:
# 0    1
# Name: tenure, dtype: int64

# %%
# Medidas de Dispersao - Desvio Padrao Tempo de Contrato
df_churn.tenure.std()
# Out:
# np.float64(24.55948102309446)

# %%
# Medidas de Dispersao - Coeficiente de Variacao Tempo de Contrato
df_churn.tenure.std() / df_churn.tenure.mean() * 100
# Out:
# np.float64(75.86842617906674)

# %%
# Quantos clientes possuem 1 mes de contrato - Filtro
len(df_churn[(df_churn.tenure == 1)])
# Out:
# 613

# %%
# Quanto os clientes de 1 mes de contrato representam percentualmente
len(df_churn[(df_churn.tenure == 1)]) / len(df_churn) * 100
# Out:
# 8.70367741019452

# %%
# Quantos clientes possuem entre 1 e 6 meses de contrato - Filtro
len(df_churn[(df_churn.tenure >= 1) & (df_churn.tenure <= 6)])
# Out:
# 1470

# %%
# Apresentar a quantidade de clientes por tempo de contrato - Agrupamento com sumarização
df_churn.groupby(['tenure'])['tenure'].count().sort_values(ascending=False)
# Out:
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %%
# Apresentar a quantidade de clientes por tempo de contrato - Agrupamento com sumarização - Em um plot
df_churn.groupby(['tenure'])['tenure'].count().sort_values().plot.barh(figsize=(20,20))
# Out:
# <Axes: ylabel='tenure'>

# %% [markdown]
# ## Analise Bivariada

# %%
# Hipotese: Clientes com contrato mensal sao mais propensos ao Churn
# Construir Tabela de Contingencia entre tipo de contrato e Churn - Quantidade
pd.crosstab(df_churn.Churn, df_churn.Contract, margins=True, margins_name='Total')
# Out:
# Contract  Month-to-month  One year  Two year  Total
# Churn
# No                  2220      1307      1647   5174
# Yes                 1655       166        48   1869
# Total               3875      1473      1695   7043

# %%
# Construir Tabela de Contingencia entre tipo de contrato e Churn - Proporcao
pd.crosstab(df_churn.Churn, df_churn.Contract, normalize='index', margins=True, margins_name='Total')
# Out:
# Contract    Month-to-month          One year          Two year
# Churn
# No       0.429068419018168 0.252609199845381 0.318322381136452
# Yes      0.885500267522739 0.088817549491707 0.025682182985554
# Total    0.550191679681954 0.209143830753940 0.240664489564106

# %% [markdown]
# Considerando o publico total, os clientes de contrato mensal representam 55%. Porem, se considerarmos apenas os clientes que abandonaram o servico, 88% tinham contrato mensal. Desta forma, podemos afirmar que ha uma correlacao entre o tipo de contrato mensal e o abandono.

# %%
# Avaliar a correlacao entre duas variaveis categoricas (qualitativas)

# Executar um teste de hipotese chamado Chi-Squared ou Qui-quadrado de Pearson
# Num teste de hipotese, duas hipoteses sao formuladas:
# H0 (hipotese Nula): as duas variaveis sao independentes
# H1 (hipotese Complementar): as duas variaveis nao sao independentes

# O teste server para confirmar ou recusar a hipotese nula (H0)
# Quando a probabilidade de observamos H0 e inferior a 0.05 (p-value) 
# recusamos a hipotese nula e seguimos com a complementar

# %%
# Gerar um DF da Crosstab (sem totais)
df_crosstab_churn_contract = pd.crosstab(df_churn.Churn, df_churn.Contract)

# %%
# Calcular os Scores e P-Values
from scipy.stats import chi2_contingency

# %%
# Tupla = Lista imutavel
chi_scores_churn_contract = chi2_contingency(df_crosstab_churn_contract)

# %%
chi_scores_churn_contract
# Out:
# Chi2ContingencyResult(statistic=np.float64(1184.5965720837926), pvalue=np.float64(5.863038300673391e-258), dof=2, expected_freq=array([[2846.69175067, 1082.11018032, 1245.198069  ],
#        [1028.30824933,  390.88981968,  449.801931  ]]))

# %%
scores_churn_contract = pd.Series(chi_scores_churn_contract[0])

# %%
pvalues_churn_contract = pd.Series(chi_scores_churn_contract[1])

# %%
# Apresentar numeros com decimais sem a notacao cientifica
pd.set_option('display.float_format', lambda x: '%.15f' % x)

# %%
# Criar DataFrame com os resultados
df_chi_scores_churn_contract = pd.DataFrame({
    'Qui2': scores_churn_contract,
    'P-Value': pvalues_churn_contract
})

# %%
# Analisar Scores e P-Values - 
df_chi_scores_churn_contract
# Out:
#                   Qui2           P-Value
# 0 1184.596572083792580 0.000000000000000

# %% [markdown]
# Conforme Teste Estatistico (Chi-Square), o P-Value <= 0.05, desta forma rejeitamos a hipotese nula, ou seja, as variaveis nao sao independentes. Pelo Qui2 alto, podemos afirmar que ha uma forte correlacao.

# %%
# Avaliar a correlacao entre uma variavel qualitativa e uma quantitativa
# User o mesmo teste de Chi-Square, mas transformar a variavel quantitativa em qualitativa
# Hipotese: Cliente com menos de 6 meses de contrato e mais propenso ao Churn

# Criar uma coluna nova no Dataframe com base numa condicao de outra coluna
# Coluna - 'TempoMenor6Meses'

import numpy as np

# %%
# Criar coluna nova
df_churn['TempoMenor6Meses'] = np.where(df_churn.tenure < 6, 'Yes', 'No')

# %%
# Checar o Dataframe
df_churn.head(5)
# Out:
#     IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0  7590-VHVEG  Female           0         Yes             No           No
# 1  5575-GNVDE    Male           0          No             No          Yes
# 2  3668-QPYBK    Male           0          No             No          Yes
# 3  7795-CFOCW    Male           0          No             No           No
# 4  9237-HQITU  Female           0          No             No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   StreamingTV StreamingMovies tenure        Contract  PaperlessBilling  \
# ...

# %%
# Gerar um DF da Crosstab (sem totais)
df_crosstab_churn_tenure = pd.crosstab(df_churn.Churn, df_churn.TempoMenor6Meses)

# %%
# Calcular os Scores e P-Values
chi_scores_churn_tenure = chi2_contingency(df_crosstab_churn_tenure)

# %%
scores_churn_tenure = pd.Series(chi_scores_churn_tenure[0])
p_values_churn_tenure = pd.Series(chi_scores_churn_tenure[1])

# %%
df_chi_scores_churn_tenure = pd.DataFrame({
    'Qui2': scores_churn_tenure,
    'P-Value': p_values_churn_tenure
})

# %%
# Analisar os resultados
df_chi_scores_churn_tenure
# Out:
#                  Qui2           P-Value
# 0 669.721615828710242 0.000000000000000

# %% [markdown]
# Como o P-Value <= 0.05, rejeitamos a H0, ou seja, as variaveis nao sao independentes. E vale mencionar que com base de Qui2 resultante das 2 analises, a correlacao entre Churn e Tempo de Contrato < 6 e menor do que a correlacao entre Churn e Tipo de Contrato.

# %%
# Correlacao entre 2 variaveis numericas
# Tenure com TotalCharges
# A intuicao e que quanto mais tempo de contrato, maior o valor pago

# Correlacao entre 2 variaveis numericas - Pearson
df_churn.tenure.corr(df_churn.TotalCharges)
# Out:
# np.float64(0.8258804609332018)

# %%
# Correlacao entre 2 variaveis numericas - Spearman
df_churn.tenure.corr(df_churn.TotalCharges, method='spearman')
# Out:
# np.float64(0.8891770805365491)

# %% [markdown]
# Ha uma forte correlacao entre Tenure e TotalCharges, usando metodos estatisticos de correlacao.

# %%
# Apresentar Plot Scatter entre Tenure e TotalCharges
# Grafico de Dispersao
df_churn.plot.scatter(x='tenure', y='TotalCharges')
# Out:
# <Axes: xlabel='tenure', ylabel='TotalCharges'>

# %% [markdown]
# - Desafio 1: Validar a primeira hipotese de que a faixa etaria do cliente tem uma forte associacao com o Churn.
# - Desafio 2: Validar com Teste de Hipotese se Contrato Mensal esta mais propenso ao Churn.

# %% [markdown]
# ## Desafio 1

# %%
# Hipotese: Clientes com mais de 65 anos sao mais propensos ao Churn
# Construir Tabela de Contingencia entre faixa etaria e Churn - Quantidade
pd.crosstab(df_churn.Churn, df_churn.Mais65Anos, margins=True, margins_name='Total')
# Out:
# Mais65Anos     0     1  Total
# Churn
# No          4508   666   5174
# Yes         1393   476   1869
# Total       5901  1142   7043

# %%
# Criar coluna nova
df_churn['FaixaEtaria'] = np.where(df_churn.Mais65Anos == 0, 'Abaixo65', 'Acima65')

# %%
# Checar o Dataframe
df_churn.head(5)
# Out:
#     IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0  7590-VHVEG  Female           0         Yes             No           No
# 1  5575-GNVDE    Male           0          No             No          Yes
# 2  3668-QPYBK    Male           0          No             No          Yes
# 3  7795-CFOCW    Male           0          No             No           No
# 4  9237-HQITU  Female           0          No             No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   StreamingMovies tenure        Contract PaperlessBilling  \
# ...

# %%
# Gerar um DF da Crosstab (sem totais)
df_crosstab_churn_acima65 = pd.crosstab(df_churn.Churn, df_churn.FaixaEtaria)
df_crosstab_churn_acima65
# Out:
# FaixaEtaria  Abaixo65  Acima65
# Churn
# No               4508      666
# Yes              1393      476

# %%
# Calcular os Scores e P-Values
chi_scores_churn_acima65 = chi2_contingency(df_crosstab_churn_acima65)
chi_scores_churn_acima65
# Out:
# Chi2ContingencyResult(statistic=np.float64(159.42630036838742), pvalue=np.float64(1.510066805092378e-36), dof=1, expected_freq=array([[4335.05239245,  838.94760755],
#        [1565.94760755,  303.05239245]]))

# %%
scores_churn_acima65 = pd.Series(chi_scores_churn_acima65[0])
p_values_churn_acima65 = pd.Series(chi_scores_churn_acima65[1])

# %%
df_chi_scores_churn_acima65= pd.DataFrame({
    'Qui2': scores_churn_acima65,
    'P-Value': p_values_churn_acima65
})

# %%
df_chi_scores_churn_acima65
# Out:
#                  Qui2           P-Value
# 0 159.426300368387416 0.000000000000000

# %% [markdown]
# Como o P-Value <= 0.05, rejeitamos a H0, ou seja, as variaveis nao sao independentes. E vale mencionar que com base de Qui2 resultante das 2 analises, a correlacao entre Churn e Faixa Etaria e forte.

# %% [markdown]
# ## Desafio 2

# %%
# Hipotese: Contrato mensal do cliente tem uma forte associacao com o Churn
# Construir Tabela de Contingencia entre com tipo de contrato e Churn - Quantidade
pd.crosstab(df_churn.Churn, df_churn.Contract, margins=True, margins_name='Total')
# Out:
# Contract  Month-to-month  One year  Two year  Total
# Churn
# No                  2220      1307      1647   5174
# Yes                 1655       166        48   1869
# Total               3875      1473      1695   7043

# %%
# Criar coluna nova
df_churn['ContratoMensal'] = np.where(df_churn.Contract == 'Month-to-month', 'Yes', 'No')

# %%
# Checar o Dataframe
df_churn.head(5)
# Out:
#     IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0  7590-VHVEG  Female           0         Yes             No           No
# 1  5575-GNVDE    Male           0          No             No          Yes
# 2  3668-QPYBK    Male           0          No             No          Yes
# 3  7795-CFOCW    Male           0          No             No           No
# 4  9237-HQITU  Female           0          No             No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ... tenure  \
# 0  No phone service             DSL             No          Yes  ...      1
# 1                No             DSL            Yes           No  ...     34
# 2                No             DSL            Yes          Yes  ...      2
# 3  No phone service             DSL            Yes           No  ...     45
# 4                No     Fiber optic             No           No  ...      2
#
# ...

# %%
# Gerar um DF da Crosstab (sem totais)
df_crosstab_churn_contratomensal = pd.crosstab(df_churn.Churn, df_churn.ContratoMensal)
df_crosstab_churn_contratomensal
# Out:
# ContratoMensal    No   Yes
# Churn
# No              2954  2220
# Yes              214  1655

# %%
# Calcular os Scores e P-Values
chi_scores_churn_contratomensal = chi2_contingency(df_crosstab_churn_contratomensal)
chi_scores_churn_contratomensal
# Out:
# Chi2ContingencyResult(statistic=np.float64(1153.971661109348), pvalue=np.float64(6.147585925548493e-253), dof=1, expected_freq=array([[2327.30824933, 2846.69175067],
#        [ 840.69175067, 1028.30824933]]))

# %%
scores_churn_contratomensal = pd.Series(chi_scores_churn_contratomensal[0])
p_values_churn_contratomensal = pd.Series(chi_scores_churn_contratomensal[1])

# %%
df_chi_scores_churn_contratomensal= pd.DataFrame({
    'Qui2': scores_churn_contratomensal,
    'P-Value': p_values_churn_contratomensal
})

# %%
df_chi_scores_churn_contratomensal
# Out:
#                   Qui2           P-Value
# 0 1153.971661109347906 0.000000000000000

# %% [markdown]
# Como o P-Value <= 0.05, rejeitamos a H0, ou seja, as variaveis nao sao independentes. E vale mencionar que com base de Qui2 resultante das 2 analises, a correlacao entre Churn e Contrato Mensal e forte.

# %%
# Faixa Etaria - Churn
df_chi_scores_churn_acima65
# Out:
#                  Qui2           P-Value
# 0 159.426300368387416 0.000000000000000

# %%
# Contrato Mensal - Churn
df_chi_scores_churn_contratomensal
# Out:
#                   Qui2           P-Value
# 0 1153.971661109347906 0.000000000000000

# %%
df_chi_scores_churn_contratomensal
# Out:
#                   Qui2           P-Value
# 0 1153.971661109347906 0.000000000000000

# %% [markdown]
# Ha uma forte correlacao entre Churn e ContratoMensal, usando metodos estatisticos de correlacao.

# %% [markdown]
# ## Detecção de Outliers (Valores Atípicos)
